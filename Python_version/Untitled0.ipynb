# %% [markdown]
# # Set directory

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/Thesis_ATOModel/Python_version')
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Thesis_ATOModel/Python_version'

# %%
import scipy.io as sio
import os
from matplotlib import pyplot as plt

# %%
cwd = os.path.dirname(os.path.abspath("utils.py"))
above_cwd = os.path.split(aa)[0]

# %%
os.path.dirname(os.getcwd())
# Out:
# '/content/drive/My Drive/Colab Notebooks/Thesis_ATOModel'

# %%
v_ref = sio.loadmat(above_cwd + '/v_ref.mat')
gradient = sio.loadmat(above_cwd + '/.mat')

# %%
len(gradient['gradient'])
# Out:
# 5001

# %%
# v_ref.keys()
plt.plot(gradient['gradient'])

# %%
import numpy as np

# %%
np.zeros(5)
# Out:
# array([0., 0., 0., 0., 0.])
